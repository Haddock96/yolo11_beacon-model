# %% [markdown]
# <a href="https://colab.research.google.com/github/Haddock96/yolo11_beacon-model/blob/main/trafficBeacons.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 905.3/905.3 kB 44.6 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xhwJjQ8fFF72ScOqOf5s")
project = rf.workspace("sensorikws24").project("traffic-beacons")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to traffic-beacons-1 in yolov11:: 100%|██████████| 804/804 [00:00<00:00, 4916.52it/s]

# %%
# !yolo detect train data=/content/pin-1/data.yaml model=yolo11s.pt epochs=30 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 18.4M/18.4M [00:00<00:00, 59.9MB/s]
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo detect train data=/content/traffic-beacons-1/data.yaml model=yolo11s.pt epochs=30 imgsz=640
# Out:
# Ultralytics 8.3.58 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("/content/runs/detect/train2/weights/best.pt")  # build a new model from YAML


# Train the model
results = model("/content/traffic-beacons-1/test/images/bake_Pics_142_jpg.rf.97745511c1d649d64eb4594f3cf38781.jpg", save=True)  # predict on an image
# Out:
# image 1/1 /content/traffic-beacons-1/test/images/bake_Pics_142_jpg.rf.97745511c1d649d64eb4594f3cf38781.jpg: 640x640 1 beacons, 15.6ms
# Speed: 2.8ms preprocess, 15.6ms inference, 513.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
